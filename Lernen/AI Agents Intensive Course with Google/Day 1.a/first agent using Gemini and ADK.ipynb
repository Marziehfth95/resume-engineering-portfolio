# %% [markdown]
# ## Konfiguration

# %% [markdown]
# ✅ Install Agent Development Kit (ADK)
#
# ✅ Configure your API key to use the Gemini model
#
# ✅ Build your first simple agent
#
# ✅ Run your agent and watch it use a tool (like Google Search) to answer a question

# %%
# %pip install google-adk
# Out:
# Requirement already satisfied: google-adk in /opt/homebrew/lib/python3.11/site-packages (1.28.1)
# Requirement already satisfied: PyYAML<7.0.0,>=6.0.2 in /opt/homebrew/lib/python3.11/site-packages (from google-adk) (6.0.3)
# Requirement already satisfied: aiosqlite>=0.21.0 in /opt/homebrew/lib/python3.11/site-packages (from google-adk) (0.22.1)
# Requirement already satisfied: anyio<5.0.0,>=4.9.0 in /opt/homebrew/lib/python3.11/site-packages (from google-adk) (4.13.0)
# Requirement already satisfied: authlib<2.0.0,>=1.6.6 in /opt/homebrew/lib/python3.11/site-packages (from google-adk) (1.6.9)
# Requirement already satisfied: click<9.0.0,>=8.1.8 in /opt/homebrew/lib/python3.11/site-packages (from google-adk) (8.3.1)
# Requirement already satisfied: fastapi<1.0.0,>=0.124.1 in /opt/homebrew/lib/python3.11/site-packages (from google-adk) (0.135.3)
# Requirement already satisfied: google-api-python-client<3.0.0,>=2.157.0 in /opt/homebrew/lib/python3.11/site-packages (from google-adk) (2.194.0)
# Requirement already satisfied: google-auth>=2.47.0 in /opt/homebrew/lib/python3.11/site-packages (from google-auth[pyopenssl]>=2.47.0->google-adk) (2.49.1)
# Requirement already satisfied: google-cloud-aiplatform<2.0.0,>=1.132.0 in /opt/homebrew/lib/python3.11/site-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.132.0->google-adk) (1.146.0)
# Requirement already satisfied: google-cloud-bigquery-storage>=2.0.0 in /opt/homebrew/lib/python3.11/site-packages (from google-adk) (2.37.0)
# Requirement already satisfied: google-cloud-bigquery>=2.2.0 in /opt/homebrew/lib/python3.11/site-packages (from google-adk) (3.41.0)
# Requirement already satisfied: google-cloud-bigtable>=2.32.0 in /opt/homebrew/lib/python3.11/site-packages (from google-adk) (2.36.0)
# Requirement already satisfied: google-cloud-dataplex<3.0.0,>=1.7.0 in /opt/homebrew/lib/python3.11/site-packages (from google-adk) (2.18.0)
# Requirement already satisfied: google-cloud-discoveryengine<0.14.0,>=0.13.12 in /opt/homebrew/lib/python3.11/site-packages (from google-adk) (0.13.12)
# Requirement already satisfied: google-cloud-pubsub<3.0.0,>=2.0.0 in /opt/homebrew/lib/python3.11/site-packages (from google-adk) (2.36.0)
# Requirement already satisfied: google-cloud-secret-manager<3.0.0,>=2.22.0 in /opt/homebrew/lib/python3.11/site-packages (from google-adk) (2.27.0)
# Requirement already satisfied: google-cloud-spanner<4.0.0,>=3.56.0 in /opt/homebrew/lib/python3.11/site-packages (from google-adk) (3.64.0)
# Requirement already satisfied: google-cloud-speech<3.0.0,>=2.30.0 in /opt/homebrew/lib/python3.11/site-packages (from google-adk) (2.38.0)
# Requirement already satisfied: google-cloud-storage<4.0.0,>=2.18.0 in /opt/homebrew/lib/python3.11/site-packages (from google-adk) (3.10.1)
# Requirement already satisfied: google-genai<2.0.0,>=1.64.0 in /opt/homebrew/lib/python3.11/site-packages (from google-adk) (1.71.0)
# Requirement already satisfied: graphviz<1.0.0,>=0.20.2 in /opt/homebrew/lib/python3.11/site-packages (from google-adk) (0.21)
# Requirement already satisfied: httpx<1.0.0,>=0.27.0 in /opt/homebrew/lib/python3.11/site-packages (from google-adk) (0.28.1)
# Requirement already satisfied: jsonschema<5.0.0,>=4.23.0 in /opt/homebrew/lib/python3.11/site-packages (from google-adk) (4.26.0)
# Requirement already satisfied: mcp<2.0.0,>=1.23.0 in /opt/homebrew/lib/python3.11/site-packages (from google-adk) (1.27.0)
# Requirement already satisfied: opentelemetry-api<1.39.0,>=1.36.0 in /opt/homebrew/lib/python3.11/site-packages (from google-adk) (1.38.0)
# Requirement already satisfied: opentelemetry-exporter-gcp-logging<2.0.0,>=1.9.0a0 in /opt/homebrew/lib/python3.11/site-packages (from google-adk) (1.11.0a0)
# Requirement already satisfied: opentelemetry-exporter-gcp-monitoring<2.0.0,>=1.9.0a0 in /opt/homebrew/lib/python3.11/site-packages (from google-adk) (1.11.0a0)
# Requirement already satisfied: opentelemetry-exporter-gcp-trace<2.0.0,>=1.9.0 in /opt/homebrew/lib/python3.11/site-packages (from google-adk) (1.11.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http>=1.36.0 in /opt/homebrew/lib/python3.11/site-packages (from google-adk) (1.38.0)
# Requirement already satisfied: opentelemetry-resourcedetector-gcp<2.0.0,>=1.9.0a0 in /opt/homebrew/lib/python3.11/site-packages (from google-adk) (1.11.0a0)
# Requirement already satisfied: opentelemetry-sdk<1.39.0,>=1.36.0 in /opt/homebrew/lib/python3.11/site-packages (from google-adk) (1.38.0)
# Requirement already satisfied: pyarrow>=14.0.0 in /opt/homebrew/lib/python3.11/site-packages (from google-adk) (23.0.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.12.0 in /opt/homebrew/lib/python3.11/site-packages (from google-adk) (2.12.5)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.9.0.post0 in /Users/marziehfattahi/Library/Python/3.11/lib/python/site-packages (from google-adk) (2.9.0.post0)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.0 in /opt/homebrew/lib/python3.11/site-packages (from google-adk) (1.2.2)
# Requirement already satisfied: requests<3.0.0,>=2.32.4 in /opt/homebrew/lib/python3.11/site-packages (from google-adk) (2.32.5)
# Requirement already satisfied: sqlalchemy-spanner>=1.14.0 in /opt/homebrew/lib/python3.11/site-packages (from google-adk) (1.17.3)
# Requirement already satisfied: sqlalchemy<3.0.0,>=2.0 in /opt/homebrew/lib/python3.11/site-packages (from google-adk) (2.0.49)
# Requirement already satisfied: starlette<1.0.0,>=0.49.1 in /opt/homebrew/lib/python3.11/site-packages (from google-adk) (0.52.1)
# Requirement already satisfied: tenacity<10.0.0,>=9.0.0 in /opt/homebrew/lib/python3.11/site-packages (from google-adk) (9.1.4)
# Requirement already satisfied: typing-extensions<5,>=4.5 in /Users/marziehfattahi/Library/Python/3.11/lib/python/site-packages (from google-adk) (4.15.0)
# Requirement already satisfied: tzlocal<6.0,>=5.3 in /opt/homebrew/lib/python3.11/site-packages (from google-adk) (5.3.1)
# Requirement already satisfied: uvicorn<1.0.0,>=0.34.0 in /opt/homebrew/lib/python3.11/site-packages (from google-adk) (0.44.0)
# Requirement already satisfied: watchdog<7.0.0,>=6.0.0 in /opt/homebrew/lib/python3.11/site-packages (from google-adk) (6.0.0)
# Requirement already satisfied: websockets<16.0.0,>=15.0.1 in /opt/homebrew/lib/python3.11/site-packages (from google-adk) (15.0.1)
# Requirement already satisfied: idna>=2.8 in /opt/homebrew/lib/python3.11/site-packages (from anyio<5.0.0,>=4.9.0->google-adk) (3.11)
# Requirement already satisfied: cryptography in /opt/homebrew/lib/python3.11/site-packages (from authlib<2.0.0,>=1.6.6->google-adk) (46.0.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/homebrew/lib/python3.11/site-packages (from fastapi<1.0.0,>=0.124.1->google-adk) (0.4.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in /opt/homebrew/lib/python3.11/site-packages (from fastapi<1.0.0,>=0.124.1->google-adk) (0.0.4)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /opt/homebrew/lib/python3.11/site-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk) (0.31.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /opt/homebrew/lib/python3.11/site-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk) (0.3.1)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 in /opt/homebrew/lib/python3.11/site-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk) (2.30.2)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /opt/homebrew/lib/python3.11/site-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk) (4.2.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.63.2 in /opt/homebrew/lib/python3.11/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client<3.0.0,>=2.157.0->google-adk) (1.74.0)
# Requirement already satisfied: protobuf<8.0.0,>=4.25.8 in /opt/homebrew/lib/python3.11/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client<3.0.0,>=2.157.0->google-adk) (6.33.6)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /opt/homebrew/lib/python3.11/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client<3.0.0,>=2.157.0->google-adk) (1.27.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/homebrew/lib/python3.11/site-packages (from google-auth>=2.47.0->google-auth[pyopenssl]>=2.47.0->google-adk) (0.4.2)
# Requirement already satisfied: packaging>=14.3 in /Users/marziehfattahi/Library/Python/3.11/lib/python/site-packages (from google-cloud-aiplatform<2.0.0,>=1.132.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.132.0->google-adk) (25.0)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0,>=1.3.3 in /opt/homebrew/lib/python3.11/site-packages (from google-cloud-aiplatform<2.0.0,>=1.132.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.132.0->google-adk) (1.17.0)
# Requirement already satisfied: docstring_parser<1 in /opt/homebrew/lib/python3.11/site-packages (from google-cloud-aiplatform<2.0.0,>=1.132.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.132.0->google-adk) (0.17.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /opt/homebrew/lib/python3.11/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.132.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.132.0->google-adk) (1.80.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /opt/homebrew/lib/python3.11/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.132.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.132.0->google-adk) (1.80.0)
# Requirement already satisfied: cloudpickle<4.0,>=3.0 in /opt/homebrew/lib/python3.11/site-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.132.0->google-adk) (3.1.2)
# Requirement already satisfied: google-cloud-trace<2 in /opt/homebrew/lib/python3.11/site-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.132.0->google-adk) (1.19.0)
# Requirement already satisfied: google-cloud-logging<4 in /opt/homebrew/lib/python3.11/site-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.132.0->google-adk) (3.15.0)
# Requirement already satisfied: google-cloud-iam in /opt/homebrew/lib/python3.11/site-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.132.0->google-adk) (2.22.0)
# Requirement already satisfied: aiohttp in /opt/homebrew/lib/python3.11/site-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.132.0->google-adk) (3.13.5)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.1 in /opt/homebrew/lib/python3.11/site-packages (from google-cloud-bigquery>=2.2.0->google-adk) (2.5.1)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.0.0 in /opt/homebrew/lib/python3.11/site-packages (from google-cloud-bigquery>=2.2.0->google-adk) (2.8.2)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0,>=0.14.0 in /opt/homebrew/lib/python3.11/site-packages (from google-cloud-dataplex<3.0.0,>=1.7.0->google-adk) (0.14.4)
# Requirement already satisfied: google-cloud-appengine-logging<2.0.0,>=0.1.3 in /opt/homebrew/lib/python3.11/site-packages (from google-cloud-logging<4->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.132.0->google-adk) (1.9.0)
# Requirement already satisfied: google-cloud-audit-log<1.0.0,>=0.3.1 in /opt/homebrew/lib/python3.11/site-packages (from google-cloud-logging<4->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.132.0->google-adk) (0.5.0)
# Requirement already satisfied: sqlparse>=0.4.4 in /opt/homebrew/lib/python3.11/site-packages (from google-cloud-spanner<4.0.0,>=3.56.0->google-adk) (0.5.5)
# Requirement already satisfied: grpc-interceptor>=0.15.4 in /opt/homebrew/lib/python3.11/site-packages (from google-cloud-spanner<4.0.0,>=3.56.0->google-adk) (0.15.4)
# Requirement already satisfied: opentelemetry-semantic-conventions>=0.43b0 in /opt/homebrew/lib/python3.11/site-packages (from google-cloud-spanner<4.0.0,>=3.56.0->google-adk) (0.59b0)
# Requirement already satisfied: google-cloud-monitoring>=2.16.0 in /opt/homebrew/lib/python3.11/site-packages (from google-cloud-spanner<4.0.0,>=3.56.0->google-adk) (2.30.0)
# Requirement already satisfied: mmh3>=4.1.0 in /opt/homebrew/lib/python3.11/site-packages (from google-cloud-spanner<4.0.0,>=3.56.0->google-adk) (5.2.1)
# Requirement already satisfied: google-crc32c<2.0.0,>=1.1.3 in /opt/homebrew/lib/python3.11/site-packages (from google-cloud-storage<4.0.0,>=2.18.0->google-adk) (1.8.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/homebrew/lib/python3.11/site-packages (from google-genai<2.0.0,>=1.64.0->google-adk) (1.9.0)
# Requirement already satisfied: sniffio in /opt/homebrew/lib/python3.11/site-packages (from google-genai<2.0.0,>=1.64.0->google-adk) (1.3.1)
# Requirement already satisfied: pyparsing<4,>=3.0.4 in /opt/homebrew/lib/python3.11/site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client<3.0.0,>=2.157.0->google-adk) (3.2.5)
# Requirement already satisfied: certifi in /opt/homebrew/lib/python3.11/site-packages (from httpx<1.0.0,>=0.27.0->google-adk) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /opt/homebrew/lib/python3.11/site-packages (from httpx<1.0.0,>=0.27.0->google-adk) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /opt/homebrew/lib/python3.11/site-packages (from httpcore==1.*->httpx<1.0.0,>=0.27.0->google-adk) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in /opt/homebrew/lib/python3.11/site-packages (from jsonschema<5.0.0,>=4.23.0->google-adk) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/homebrew/lib/python3.11/site-packages (from jsonschema<5.0.0,>=4.23.0->google-adk) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/homebrew/lib/python3.11/site-packages (from jsonschema<5.0.0,>=4.23.0->google-adk) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /opt/homebrew/lib/python3.11/site-packages (from jsonschema<5.0.0,>=4.23.0->google-adk) (0.30.0)
# Requirement already satisfied: httpx-sse>=0.4 in /opt/homebrew/lib/python3.11/site-packages (from mcp<2.0.0,>=1.23.0->google-adk) (0.4.3)
# Requirement already satisfied: pydantic-settings>=2.5.2 in /opt/homebrew/lib/python3.11/site-packages (from mcp<2.0.0,>=1.23.0->google-adk) (2.13.1)
# Requirement already satisfied: pyjwt>=2.10.1 in /opt/homebrew/lib/python3.11/site-packages (from pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.23.0->google-adk) (2.12.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /opt/homebrew/lib/python3.11/site-packages (from mcp<2.0.0,>=1.23.0->google-adk) (0.0.24)
# Requirement already satisfied: sse-starlette>=1.6.1 in /opt/homebrew/lib/python3.11/site-packages (from mcp<2.0.0,>=1.23.0->google-adk) (3.3.4)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /opt/homebrew/lib/python3.11/site-packages (from opentelemetry-api<1.39.0,>=1.36.0->google-adk) (8.7.1)
# Requirement already satisfied: zipp>=3.20 in /opt/homebrew/lib/python3.11/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api<1.39.0,>=1.36.0->google-adk) (3.23.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.38.0 in /opt/homebrew/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-http>=1.36.0->google-adk) (1.38.0)
# Requirement already satisfied: opentelemetry-proto==1.38.0 in /opt/homebrew/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-http>=1.36.0->google-adk) (1.38.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/homebrew/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.12.0->google-adk) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /opt/homebrew/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.12.0->google-adk) (2.41.5)
# Requirement already satisfied: six>=1.5 in /Users/marziehfattahi/Library/Python/3.11/lib/python/site-packages (from python-dateutil<3.0.0,>=2.9.0.post0->google-adk) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/homebrew/lib/python3.11/site-packages (from requests<3.0.0,>=2.32.4->google-adk) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/lib/python3.11/site-packages (from requests<3.0.0,>=2.32.4->google-adk) (2.5.0)
# Requirement already satisfied: cffi>=2.0.0 in /opt/homebrew/lib/python3.11/site-packages (from cryptography->authlib<2.0.0,>=1.6.6->google-adk) (2.0.0)
# Requirement already satisfied: pycparser in /opt/homebrew/lib/python3.11/site-packages (from cffi>=2.0.0->cryptography->authlib<2.0.0,>=1.6.6->google-adk) (3.0)
# Requirement already satisfied: pyopenssl>=20.0.0 in /opt/homebrew/lib/python3.11/site-packages (from google-auth[pyopenssl]>=2.47.0->google-adk) (26.0.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /opt/homebrew/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth>=2.47.0->google-auth[pyopenssl]>=2.47.0->google-adk) (0.6.3)
# Requirement already satisfied: alembic in /opt/homebrew/lib/python3.11/site-packages (from sqlalchemy-spanner>=1.14.0->google-adk) (1.18.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.132.0->google-adk) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.132.0->google-adk) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.132.0->google-adk) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.132.0->google-adk) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.132.0->google-adk) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.132.0->google-adk) (1.23.0)
# Requirement already satisfied: Mako in /opt/homebrew/lib/python3.11/site-packages (from alembic->sqlalchemy-spanner>=1.14.0->google-adk) (1.3.10)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /opt/homebrew/lib/python3.11/site-packages (from Mako->alembic->sqlalchemy-spanner>=1.14.0->google-adk) (3.0.3)
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: /opt/homebrew/opt/python@3.11/bin/python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install python-dotenv
# Out:
# Requirement already satisfied: python-dotenv in /opt/homebrew/lib/python3.11/site-packages (1.2.2)
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: /opt/homebrew/opt/python@3.11/bin/python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Code, um das Problem bei API_Key zu beheben.
# So kann man sagen,welches unsichtbare Zeichen drin ist und wie wir es endgültig fixen (oder ohne dotenv laden)

# %%
from dotenv import load_dotenv, find_dotenv, dotenv_values
from pathlib import Path
import os

cwd = Path.cwd()

candidates = [
    cwd / ".env",
    cwd.parent / ".env",
]

loaded = None
for c in candidates:
    if c.exists():
        load_dotenv(c, override=True)
        loaded = c
        break

if loaded is None:
    # fallback: search upwards from current working directory
    found = find_dotenv(usecwd=True)
    if found:
        load_dotenv(found, override=True)
        loaded = Path(found)

if loaded is None:
    raise FileNotFoundError(f"No .env found. Tried: {[str(c) for c in candidates]} and find_dotenv")

# Byte level debug (reveals BOM / CRLF / hidden chars)
raw = loaded.read_bytes()[:80]
print("first_bytes_repr=", repr(raw))

parsed = dotenv_values(str(loaded))

print("cwd=", str(cwd))
print("loaded_env=", str(loaded))
print("parsed_keys=", sorted([k for k in parsed.keys() if k]))
print("dotenv_has_GOOGLE_API_KEY=", "GOOGLE_API_KEY" in parsed)

# Ensure current process env is updated
load_dotenv(str(loaded), override=True)

print("process_has_GOOGLE_API_KEY=", "GOOGLE_API_KEY" in os.environ)
print("value_is_none=", os.getenv("GOOGLE_API_KEY") is None)
print("value_length=", None if os.getenv("GOOGLE_API_KEY") is None else len(os.getenv("GOOGLE_API_KEY")))
# Out:
# first_bytes_repr= b'GOOGLE_API_KEY=AIzaSyDHPEJPS3n7iR4gJpXlPS8s2bGGXd8wYPc'
# cwd= /Users/marziehfattahi/Documents/New project/resume-engineering-portfolio/Training/python/AI Agents Intensive Course with Google/Day 1.a
# loaded_env= /Users/marziehfattahi/Documents/New project/resume-engineering-portfolio/Training/python/AI Agents Intensive Course with Google/.env
# parsed_keys= ['GOOGLE_API_KEY']
# dotenv_has_GOOGLE_API_KEY= True
# process_has_GOOGLE_API_KEY= True
# value_is_none= False
# value_length= 39

# %% [markdown]
#  import the specific components We'll need from the Agent Development Kit and the Generative AI library.
#
#  This keeps code organized and ensures we have access to the necessary building block

# %%
from google.adk.agents import Agent
from google.adk.models.google_llm import Gemini
from google.adk.runners import InMemoryRunner
from google.adk.tools import google_search
from google.genai import types

print("✅ ADK components imported successfully.")
# Out:
# ✅ ADK components imported successfully.

# %% [markdown]
# When working with LLMs, you may encounter transient errors like rate limits or temporary service unavailability. Retry options automatically handle these failures by retrying the request with exponential backoff.

# %%
retry_config=types.HttpRetryOptions(
    # Maximum retry attempts
    attempts=5,  
    # Delay multiplier
    exp_base=7, 
    # Initial delay before first retry (in seconds)
    initial_delay=1, 
    # Retry on these HTTP errors
    http_status_codes=[429, 500, 503, 504] 
)

# %% [markdown]
# ## first AI Agent with ADK

# %% [markdown]
# In this notebook, we'll build an agent that can take the action of searching Google.

# %% [markdown]
# #### Drei Haupttypen von Agents
# 1. LLM Agents
#
# Beispiele:
#
# LlmAgent
# Agent
#
# Diese Agents nutzen Large Language Models (LLMs) wie GPT oder Gemini.
#
# Sie können:
#
# natürliche Sprache verstehen
# Antworten generieren
# Entscheidungen treffen
# Tools auswählen
#
# Eigenschaften:
#
# flexibel
# intelligent
# aber nicht immer deterministisch (das Ergebnis kann variieren)
#
# Typische Anwendungen:
#
# Chatbots
# Assistenten
# Analyse von Text
# dynamische Entscheidungsfindung
# 2. Workflow Agents
#
# Beispiele:
#
# SequentialAgent
# ParallelAgent
# LoopAgent
#
# Diese Agents steuern den Ablauf anderer Agents.
#
# Sie verwenden kein LLM für die Steuerung, sondern fest definierte Logik.
#
# Beispiele für Abläufe:
#
# Sequence → Aufgaben nacheinander
# Parallel → Aufgaben gleichzeitig
# Loop → Aufgaben wiederholen
#
# Eigenschaften:
#
# deterministisch
# vorhersehbar
# gut für strukturierte Prozesse
# 3. Custom Agents
#
# Diese werden erstellt, indem man BaseAgent direkt erweitert.
#
# Sie erlauben:
#
# eigene Logik
# spezielle Integrationen
# individuelle Workflows
#
# Eigenschaften:
#
# maximal flexibel
# komplett anpassbar
# 3. Multi-Agent Systeme
#
# In komplexen Anwendungen arbeiten mehrere Agents zusammen.
#
# Typische Rollen:
#
# Agent-Typ	Aufgabe
#
# LLM Agent	Denken, analysieren, Sprache verstehen
#
# Workflow Agent	Ablauf der Aufgaben steuern
#
# Custom Agent	Spezialfunktionen implementieren
#
# Diese Kombination nennt man Multi-Agent-System.

# %% [markdown]
# ### These are the main properties we'll set:
#
# name and description: A simple name and description to identify our agent.
#
# model: The specific LLM that will power the agent's reasoning. We'll use "gemini-2.5-flash-lite".
#
# instruction: The agent's guiding prompt. This tells the agent what its goal is and how to behave.
#
# tools: A list of tools that the agent can use. To start, we'll give it the google_search tool, which lets it find up-to-date information online.

# %%
root_agent= Agent(
    name= "helpful_assistant",
    model= Gemini(
        model_name= "gemini-2.5-flash-lite",
        retry_options= retry_config),
        description="A simple agent that can answer general questions.",
        instruction="You are a helpful assistant. Use Google Search for current info or if unsure.",
        tools= [google_search]
)
print("Root Agent defined.")
# Out:
# Root Agent defined.

# %% [markdown]
# Now it's time to bring your agent to life and send it a query. To do this, you need a Runner, which is the central component within ADK that acts as the orchestrator. It manages the conversation, sends our messages to the agent, and handles its responses.

# %%
# Create an InMemoryRunner and tell it to use our root_agent:
runner = InMemoryRunner(agent=root_agent)
print("Runner created.")
# Out:
# Runner created.

# %%
from dotenv import load_dotenv, dotenv_values
from pathlib import Path
import os
import asyncio

# Self-heal: ensure API key exists even if cells were run out of order
if not os.getenv("GOOGLE_API_KEY"):
    for p in [Path.cwd() / ".env", Path.cwd().parent / ".env"]:
        if p.exists():
            load_dotenv(p, override=True)
            parsed = dotenv_values(str(p))
            # Force set in process env in case dotenv didn't export into os.environ
            if parsed.get("GOOGLE_API_KEY"):
                os.environ["GOOGLE_API_KEY"] = parsed["GOOGLE_API_KEY"]
            break

if not os.getenv("GOOGLE_API_KEY"):
    raise ValueError("GOOGLE_API_KEY is missing. Run the env setup cell first or create ../.env")

print("GOOGLE_API_KEY loaded in process:", bool(os.getenv("GOOGLE_API_KEY")))

prompt = "What is Agent Development Kit from Google? What languages is the SDK available in?"
max_attempts = 6

for attempt in range(1, max_attempts + 1):
    try:
        response = await runner.run_debug(prompt)
        break
    except Exception as e:
        err = str(e)
        is_overload = "503" in err and "UNAVAILABLE" in err
        if not is_overload or attempt == max_attempts:
            raise
        wait_s = min(2 ** attempt, 30)
        print(f"Model overloaded (attempt {attempt}/{max_attempts}). Retrying in {wait_s}s...")
        await asyncio.sleep(wait_s)
# Out:
# GOOGLE_API_KEY loaded in process: True
#
#  ### Continue session: debug_session_id
#
# User > What is Agent Development Kit from Google? What languages is the SDK available in?
# helpful_assistant > The Agent Development Kit (ADK) from Google is an open-source framework designed to simplify the end-to-end development of intelligent, autonomous AI agents and multi-agent systems. Introduced at Google Cloud NEXT 2025, ADK aims to empower developers to build production-ready agentic applications with greater flexibility and precise control. It is the same framework that powers agents within Google products like Agentspace and the Google Customer Engagement Suite (CES).
#
# While ADK offers flexibility to work with various tools, it is optimized for seamless integration within the Google Cloud ecosystem, specifically with Gemini models and Vertex AI. It allows developers to define agent behavior, orchestration, and tool use directly in code, enabling robust debugging, reliable versioning, and deployment anywhere from a local machine to the cloud. Key features include precise control over agent behavior and orchestration, a rich tool ecosystem, and the ability to design scalable applications by composing multiple specialized agents into flexible hierarchies. ADK also supports the Agent2Agent (A2A) protocol for multi-agent orchestration.
#
# The Agent Development Kit SDK is available in the following programming languages:
# *   Python
# *   Java
# *   Go
# *   TypeScript

# %% [markdown]
# The agent performed a Google Search to get the latest information about ADK, and it knew to use this tool because:
#
# The agent inspects and is aware of which tools it has available to use.
# The agent's instructions specify the use of the search tool to get current information or if it is unsure of an answer.
# The best way to see the full, detailed trace of the agent's thoughts and actions is in the ADK web UI, which we'll set up later in this notebook.

# %%
import asyncio

prompt = "What's the weather in London?"
max_attempts = 6

response = None
for attempt in range(1, max_attempts + 1):
    try:
        response = await runner.run_debug(prompt)
        break
    except Exception as e:
        err = str(e)
        is_overload = "503" in err and "UNAVAILABLE" in err
        if not is_overload:
            raise

        # Last retry failed: switch to a fallback model and try once more
        if attempt == max_attempts:
            print("Primary model overloaded. Switching to fallback model gemini-2.0-flash...")
            fallback_agent = Agent(
                name="helpful_assistant_fallback",
                model=Gemini(model_name="gemini-2.0-flash", retry_options=retry_config),
                description="Fallback agent for overload situations.",
                instruction="You are a helpful assistant. Use Google Search for current info or if unsure.",
                tools=[google_search],
            )
            fallback_runner = InMemoryRunner(agent=fallback_agent)
            response = await fallback_runner.run_debug(prompt)
            break

        wait_s = min(2 ** attempt, 30)
        print(f"Model overloaded (attempt {attempt}/{max_attempts}). Retrying in {wait_s}s...")
        await asyncio.sleep(wait_s)
# Out:
#  ### Continue session: debug_session_id
#
# User > What's the weather in London?
# helpful_assistant > The weather in London, UK, is currently cloudy with a temperature of 46°F (8°C). It feels like 46°F (8°C), and the humidity is around 58%. There is a 10% chance of rain today.
#
# The forecast for today, Friday, April 10, 2026, indicates cloudy conditions throughout the day and night, with a 10% chance of rain during the day and a 25% chance at night. Temperatures are expected to range between 43°F (6°C) and 54°F (12°C).

# %% [markdown]
# ## Try the ADK Web Interface

# %%
# Local Jupyter/Cursor environment: no Kaggle proxy helper needed
url_prefix = ""

print("Start ADK Web UI with:")
print("  adk web . --port 8000")
print("Open:")
print(f"  http://127.0.0.1:8000{url_prefix}")
# Out:
# Start ADK Web UI with:
#   adk web . --port 8000
# Open:
#   http://127.0.0.1:8000
